# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from keras.datasets import cifar10
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import os
import torch
import tarfile
import imageio
import tarfile
import pandas as pd
import numpy as np
import torchvision
from PIL import Image
import seaborn as sns
import torchvision.models as models
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torchvision.transforms as T
from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid
import matplotlib
# %matplotlib inline
import torchvision.transforms as transforms
import torchvision.transforms as tt
from torchvision.datasets.utils import download_url
from torch.utils.data import Dataset, random_split, DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
import torch.nn as nn
import torch.nn.functional as F

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2

# %%
labels = ['box', 'chevron', 'rounded']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                #img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                #edges = cv2.Canny(img_arr,10,20)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
test = get_data("/content/drive/MyDrive/fold/TEST")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
val = get_data("/content/drive/MyDrive/fold/VAL")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
train = get_data("/content/drive/MyDrive/fold/TRAIN")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# labels = ['box', 'chevron', 'rounded']
# img_size = 150
# def get_data(data_dir):
#     data = [] 
#     for label in labels: 
#         path = os.path.join(data_dir, label)
#         class_num = labels.index(label)
#         for img in os.listdir(path):
#             try:
#                 img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
#                 #img_arr = cv2.imread(os.path.join(path, img), 0)
#                 #edges = cv2.Canny(img_arr,10,20)
#                 resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
#                 data.append([resized_arr, class_num])
#             except Exception as e:
#                 print(e)
#     return np.array(data)
# #train = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TRAIN")
# val = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL")
# test = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TEST")

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("chevron")
    elif(i[1] == 1):
        l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in val:
    if(i[1] == 0):
        l.append("chevron")
    elif(i[1] == 1):
        l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in test:
    if(i[1] == 0):
        l.append("chevron")
    elif(i[1] == 1):
        l.append("rounded")
    else:
        l.append("box")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[100][0])
plt.title(labels[train[100][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1000][0])
plt.title(labels[train[1000][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1500][0])
plt.title(labels[train[1500][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[800][0])
plt.title(labels[train[800][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(val[45][0])
plt.title(labels[val[45][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(val[15][0])
plt.title(labels[val[15][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(val[50][0])
plt.title(labels[val[50][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(test[2][0])
plt.title(labels[test[2][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(test[1][0])
plt.title(labels[test[1][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(test[20][0])
plt.title(labels[test[2][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
plt.figure(figsize = (5,5))
plt.imshow(test[12][0])
plt.title(labels[test[12][1]])
# Out:
# Text(0.5, 1.0, 'box')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
print(type(x_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(type(x_test))
print(type(y_test))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
datagen = ImageDataGenerator(
        featurewise_center=True,  # set input mean to 0 over the dataset
        samplewise_center=True,  # set each sample mean to 0
        featurewise_std_normalization=True,  # divide inputs by std of the dataset
        samplewise_std_normalization=True,  # divide each input by its std
        #zca_whitening=True,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=True
        )  # randomly flip images


datagen.fit(x_train)
#datagen.fit(x_test)

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(512 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.3))
model.add(Dense(units = 3 , activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,654,019
# Trainable params: 2,654,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "Adam" , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])

# %%
lr=0.000001

history = model.fit(datagen.flow(x_train,y_train, batch_size=128),
                    epochs = 500 , 
                    validation_data = datagen.flow(x_val, y_val))
# Out:
# Epoch 1/500
# 26/26 [==============================] - 42s 419ms/step - loss: 1.2835 - accuracy: 0.3727 - val_loss: 1.1402 - val_accuracy: 0.3267
# Epoch 2/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.9651 - accuracy: 0.5121 - val_loss: 1.1077 - val_accuracy: 0.3267
# Epoch 3/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.9145 - accuracy: 0.6024 - val_loss: 1.1756 - val_accuracy: 0.3133
# Epoch 4/500
# 26/26 [==============================] - 9s 340ms/step - loss: 0.8208 - accuracy: 0.6637 - val_loss: 1.2349 - val_accuracy: 0.3233
# Epoch 5/500
# 26/26 [==============================] - 9s 337ms/step - loss: 0.7370 - accuracy: 0.6807 - val_loss: 1.1672 - val_accuracy: 0.2900
# Epoch 6/500
# 26/26 [==============================] - 9s 341ms/step - loss: 0.7137 - accuracy: 0.6931 - val_loss: 1.1287 - val_accuracy: 0.2900
# Epoch 7/500
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6120 - accuracy: 0.7369 - val_loss: 1.1059 - val_accuracy: 0.3567
# Epoch 8/500
# 26/26 [==============================] - 9s 338ms/step - loss: 0.5580 - accuracy: 0.7699 - val_loss: 1.0895 - val_accuracy: 0.3533
# Epoch 9/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.5222 - accuracy: 0.7844 - val_loss: 1.1288 - val_accuracy: 0.3633
# Epoch 10/500
# 26/26 [==============================] - 9s 341ms/step - loss: 0.4850 - accuracy: 0.7977 - val_loss: 1.0907 - val_accuracy: 0.3700
# Epoch 11/500
# 26/26 [==============================] - 9s 341ms/step - loss: 0.4502 - accuracy: 0.8072 - val_loss: 1.1160 - val_accuracy: 0.3367
# Epoch 12/500
# 26/26 [==============================] - 9s 337ms/step - loss: 0.4272 - accuracy: 0.8151 - val_loss: 1.1067 - val_accuracy: 0.3467
# Epoch 13/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.4126 - accuracy: 0.8286 - val_loss: 1.0909 - val_accuracy: 0.3367
# Epoch 14/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.3843 - accuracy: 0.8426 - val_loss: 1.0927 - val_accuracy: 0.3167
# Epoch 15/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.3857 - accuracy: 0.8498 - val_loss: 1.0940 - val_accuracy: 0.3667
# Epoch 16/500
# 26/26 [==============================] - 9s 342ms/step - loss: 0.3752 - accuracy: 0.8456 - val_loss: 1.0845 - val_accuracy: 0.3867
# Epoch 17/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.3348 - accuracy: 0.8620 - val_loss: 1.0929 - val_accuracy: 0.3500
# Epoch 18/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.3287 - accuracy: 0.8673 - val_loss: 1.0536 - val_accuracy: 0.3600
# Epoch 19/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.3160 - accuracy: 0.8564 - val_loss: 1.0738 - val_accuracy: 0.3633
# Epoch 20/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.3189 - accuracy: 0.8652 - val_loss: 1.1176 - val_accuracy: 0.3167
# Epoch 21/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.3168 - accuracy: 0.8723 - val_loss: 1.0590 - val_accuracy: 0.4200
# Epoch 22/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.3102 - accuracy: 0.8680 - val_loss: 1.0840 - val_accuracy: 0.3233
# Epoch 23/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.2949 - accuracy: 0.8770 - val_loss: 1.0788 - val_accuracy: 0.3733
# Epoch 24/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.2764 - accuracy: 0.8882 - val_loss: 1.0674 - val_accuracy: 0.3967
# Epoch 25/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.3174 - accuracy: 0.8675 - val_loss: 1.0692 - val_accuracy: 0.4300
# Epoch 26/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.2600 - accuracy: 0.8909 - val_loss: 1.0513 - val_accuracy: 0.4267
# Epoch 27/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.2846 - accuracy: 0.8783 - val_loss: 1.0733 - val_accuracy: 0.4167
# Epoch 28/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.2297 - accuracy: 0.8982 - val_loss: 1.0463 - val_accuracy: 0.4067
# Epoch 29/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.2524 - accuracy: 0.8912 - val_loss: 1.0717 - val_accuracy: 0.4167
# Epoch 30/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.2719 - accuracy: 0.8916 - val_loss: 1.0501 - val_accuracy: 0.4267
# Epoch 31/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.2625 - accuracy: 0.8909 - val_loss: 1.0402 - val_accuracy: 0.4700
# Epoch 32/500
# 26/26 [==============================] - 9s 341ms/step - loss: 0.2425 - accuracy: 0.8979 - val_loss: 1.0792 - val_accuracy: 0.4333
# Epoch 33/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.2160 - accuracy: 0.9106 - val_loss: 1.0659 - val_accuracy: 0.4267
# Epoch 34/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.2465 - accuracy: 0.8926 - val_loss: 1.0998 - val_accuracy: 0.4433
# Epoch 35/500
# 26/26 [==============================] - 9s 342ms/step - loss: 0.2822 - accuracy: 0.8860 - val_loss: 1.0840 - val_accuracy: 0.3700
# Epoch 36/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.2174 - accuracy: 0.9022 - val_loss: 1.0789 - val_accuracy: 0.4333
# Epoch 37/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.2161 - accuracy: 0.9058 - val_loss: 1.0459 - val_accuracy: 0.4333
# Epoch 38/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.2118 - accuracy: 0.9041 - val_loss: 1.0464 - val_accuracy: 0.4300
# Epoch 39/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.1949 - accuracy: 0.9170 - val_loss: 1.0218 - val_accuracy: 0.4433
# Epoch 40/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.2062 - accuracy: 0.9117 - val_loss: 1.0461 - val_accuracy: 0.4333
# Epoch 41/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.2324 - accuracy: 0.9025 - val_loss: 1.0496 - val_accuracy: 0.4200
# Epoch 42/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.2069 - accuracy: 0.9129 - val_loss: 1.0194 - val_accuracy: 0.4533
# Epoch 43/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.2139 - accuracy: 0.9033 - val_loss: 1.0288 - val_accuracy: 0.4333
# Epoch 44/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.1936 - accuracy: 0.9148 - val_loss: 1.0557 - val_accuracy: 0.4500
# Epoch 45/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.2064 - accuracy: 0.9068 - val_loss: 0.9987 - val_accuracy: 0.4900
# Epoch 46/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.1879 - accuracy: 0.9215 - val_loss: 1.0141 - val_accuracy: 0.4667
# Epoch 47/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0
500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.1797 - accuracy: 0.9201 - val_loss: 0.9125 - val_accuracy: 0.5400
# Epoch 103/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.1430 - accuracy: 0.9357 - val_loss: 0.8973 - val_accuracy: 0.5633
# Epoch 104/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.1231 - accuracy: 0.9519 - val_loss: 0.9009 - val_accuracy: 0.5767
# Epoch 105/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.1490 - accuracy: 0.9442 - val_loss: 0.8861 - val_accuracy: 0.5533
# Epoch 106/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.1466 - accuracy: 0.9375 - val_loss: 0.8601 - val_accuracy: 0.5967
# Epoch 107/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.1512 - accuracy: 0.9356 - val_loss: 0.8649 - val_accuracy: 0.6000
# Epoch 108/500
# 26/26 [==============================] - 9s 352ms/step - loss: 0.1609 - accuracy: 0.9306 - val_loss: 0.8846 - val_accuracy: 0.5633
# Epoch 109/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.1339 - accuracy: 0.9371 - val_loss: 0.9071 - val_accuracy: 0.5367
# Epoch 110/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.1405 - accuracy: 0.9443 - val_loss: 0.9235 - val_accuracy: 0.4967
# Epoch 111/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.1436 - accuracy: 0.9446 - val_loss: 0.9514 - val_accuracy: 0.5000
# Epoch 112/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.1279 - accuracy: 0.9509 - val_loss: 0.8906 - val_accuracy: 0.5433
# Epoch 113/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.1348 - accuracy: 0.9453 - val_loss: 0.8695 - val_accuracy: 0.5633
# Epoch 114/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.1368 - accuracy: 0.9451 - val_loss: 0.9393 - val_accuracy: 0.5200
# Epoch 115/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.1337 - accuracy: 0.9422 - val_loss: 0.8865 - val_accuracy: 0.5400
# Epoch 116/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.1374 - accuracy: 0.9456 - val_loss: 0.9126 - val_accuracy: 0.5600
# Epoch 117/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.1336 - accuracy: 0.9416 - val_loss: 0.9204 - val_accuracy: 0.5600
# Epoch 118/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.1475 - accuracy: 0.9308 - val_loss: 0.8164 - val_accuracy: 0.5967
# Epoch 119/500
# 26/26 [==============================] - 9s 352ms/step - loss: 0.1466 - accuracy: 0.9400 - val_loss: 0.8912 - val_accuracy: 0.5833
# Epoch 120/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.1296 - accuracy: 0.9461 - val_loss: 0.8966 - val_accuracy: 0.5467
# Epoch 121/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.1266 - accuracy: 0.9473 - val_loss: 0.8547 - val_accuracy: 0.5733
# Epoch 122/500
# 26/26 [==============================] - 9s 353ms/step - loss: 0.1623 - accuracy: 0.9331 - val_loss: 0.8881 - val_accuracy: 0.5933
# Epoch 123/500
# 26/26 [==============================] - 9s 353ms/step - loss: 0.1298 - accuracy: 0.9434 - val_loss: 0.9050 - val_accuracy: 0.5600
# Epoch 124/500
# 26/26 [==============================] - 9s 359ms/step - loss: 0.1229 - accuracy: 0.9466 - val_loss: 0.9054 - val_accuracy: 0.5467
# Epoch 125/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.1271 - accuracy: 0.9474 - val_loss: 0.9033 - val_accuracy: 0.5567
# Epoch 126/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.1282 - accuracy: 0.9491 - val_loss: 0.8626 - val_accuracy: 0.5900
# Epoch 127/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.1202 - accuracy: 0.9481 - val_loss: 0.8422 - val_accuracy: 0.5733
# Epoch 128/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.1109 - accuracy: 0.9532 - val_loss: 0.9377 - val_accuracy: 0.5033
# Epoch 129/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.1150 - accuracy: 0.9510 - val_loss: 0.8952 - val_accuracy: 0.5700
# Epoch 130/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.1512 - accuracy: 0.9427 - val_loss: 0.8772 - val_accuracy: 0.5400
# Epoch 131/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.
500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0783 - accuracy: 0.9671 - val_loss: 0.7686 - val_accuracy: 0.6500
# Epoch 394/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.0767 - accuracy: 0.9726 - val_loss: 0.7130 - val_accuracy: 0.7167
# Epoch 395/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0653 - accuracy: 0.9763 - val_loss: 0.8074 - val_accuracy: 0.6667
# Epoch 396/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0713 - accuracy: 0.9703 - val_loss: 0.7633 - val_accuracy: 0.6633
# Epoch 397/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.0802 - accuracy: 0.9647 - val_loss: 0.7509 - val_accuracy: 0.6033
# Epoch 398/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.0873 - accuracy: 0.9627 - val_loss: 0.8069 - val_accuracy: 0.6267
# Epoch 399/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0625 - accuracy: 0.9761 - val_loss: 0.7280 - val_accuracy: 0.6600
# Epoch 400/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.0596 - accuracy: 0.9790 - val_loss: 0.8242 - val_accuracy: 0.6500
# Epoch 401/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0529 - accuracy: 0.9777 - val_loss: 0.8571 - val_accuracy: 0.6433
# Epoch 402/500
# 26/26 [==============================] - 9s 352ms/step - loss: 0.0718 - accuracy: 0.9700 - val_loss: 0.7688 - val_accuracy: 0.6433
# Epoch 403/500
# 26/26 [==============================] - 9s 353ms/step - loss: 0.0870 - accuracy: 0.9679 - val_loss: 0.7575 - val_accuracy: 0.6633
# Epoch 404/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0818 - accuracy: 0.9700 - val_loss: 0.7633 - val_accuracy: 0.6733
# Epoch 405/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0619 - accuracy: 0.9720 - val_loss: 0.7174 - val_accuracy: 0.6767
# Epoch 406/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0695 - accuracy: 0.9711 - val_loss: 0.8451 - val_accuracy: 0.6400
# Epoch 407/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0697 - accuracy: 0.9759 - val_loss: 0.7546 - val_accuracy: 0.6667
# Epoch 408/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0578 - accuracy: 0.9786 - val_loss: 0.7903 - val_accuracy: 0.6833
# Epoch 409/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0649 - accuracy: 0.9820 - val_loss: 0.7713 - val_accuracy: 0.6833
# Epoch 410/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0631 - accuracy: 0.9744 - val_loss: 0.9529 - val_accuracy: 0.5867
# Epoch 411/500
# 26/26 [==============================] - 9s 353ms/step - loss: 0.0831 - accuracy: 0.9720 - val_loss: 0.8210 - val_accuracy: 0.6233
# Epoch 412/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0713 - accuracy: 0.9726 - val_loss: 0.7946 - val_accuracy: 0.6333
# Epoch 413/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0774 - accuracy: 0.9768 - val_loss: 0.7745 - val_accuracy: 0.6767
# Epoch 414/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0611 - accuracy: 0.9810 - val_loss: 0.8013 - val_accuracy: 0.6667
# Epoch 415/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0565 - accuracy: 0.9782 - val_loss: 0.7955 - val_accuracy: 0.6667
# Epoch 416/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0616 - accuracy: 0.9754 - val_loss: 0.8533 - val_accuracy: 0.6433
# Epoch 417/500
# 26/26 [==============================] - 9s 354ms/step - loss: 0.0679 - accuracy: 0.9713 - val_loss: 0.7627 - val_accuracy: 0.6767
# Epoch 418/500
# 26/26 [==============================] - 9s 352ms/step - loss: 0.0561 - accuracy: 0.9792 - val_loss: 0.7723 - val_accuracy: 0.6800
# Epoch 419/500
# 26/26 [==============================] - 9s 352ms/step - loss: 0.0751 - accuracy: 0.9694 - val_loss: 0.7869 - val_accuracy: 0.6533
# Epoch 420/500
# 26/26 [==============================] - 9s 354ms/step - loss: 0.0795 - accuracy: 0.9713 - val_loss: 0.7645 - val_accuracy: 0.6567
# Epoch 421/500
# 26/26 [==============================] - 9s 355ms/step - loss: 0.0777 - accuracy: 0.9769 - val_loss: 0.7588 - val_accuracy: 0.6233
# Epoch 422/500
# 26/26 [==============================] - 10s 362ms/step - loss: 0.0657 - accuracy: 0.9719 - val_loss: 0.8213 - val_accuracy: 0.5967
# Epoch 423/500
# 26/26 [==============================] - 9s 359ms/step - loss: 0.0604 - accuracy: 0.9784 - val_loss: 0.7728 - val_accuracy: 0.6833
# Epoch 424/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0648 - accuracy: 0.9721 - val_loss: 0.7344 - val_accuracy: 0.6900
# Epoch 425/500
# 26/26 [==============================] - 9s 352ms/step - loss: 0.0718 - accuracy: 0.9811 - val_loss: 0.7964 - val_accuracy: 0.6767
# Epoch 426/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0685 - accuracy: 0.9730 - val_loss: 0.7922 - val_accuracy: 0.6533
# Epoch 427/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0631 - accuracy: 0.9746 - val_loss: 0.8468 - val_accuracy: 0.6200
# Epoch 428/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0603 - accuracy: 0.9780 - val_loss: 0.7858 - val_accuracy: 0.6500
# Epoch 429/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0570 - accuracy: 0.9808 - val_loss: 0.8086 - val_accuracy: 0.6233
# Epoch 430/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0608 - accuracy: 0.9742 - val_loss: 0.7091 - val_accuracy: 0.6900
# Epoch 431/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0707 - accuracy: 0.9749 - val_loss: 0.7589 - val_accuracy: 0.6667
# Epoch 432/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0709 - accuracy: 0.9730 - val_loss: 0.7330 - val_accuracy: 0.6900
# Epoch 433/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0702 - accuracy: 0.9757 - val_loss: 0.8083 - val_accuracy: 0.6500
# Epoch 434/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.0717 - accuracy: 0.9731 - val_loss: 0.8232 - val_accuracy: 0.6567
# Epoch 435/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0673 - accuracy: 0.9767 - val_loss: 0.7716 - val_accuracy: 0.6967
# Epoch 436/500
# 26/26 [==============================] - 9s 364ms/step - loss: 0.0590 - accuracy: 0.9731 - val_loss: 0.8386 - val_accuracy: 0.6367
# Epoch 437/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0497 - accuracy: 0.9804 - val_loss: 0.8018 - val_accuracy: 0.6400
# Epoch 438/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0649 - accuracy: 0.9787 - val_loss: 0.7267 - val_accuracy: 0.6967
# Epoch 439/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0721 - accuracy: 0.9780 - val_loss: 0.7691 - val_accuracy: 0.6633
# Epoch 440/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0627 - accuracy: 0.9757 - val_loss: 0.8482 - val_accuracy: 0.6567
# Epoch 441/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0517 - accuracy: 0.9825 - val_loss: 0.7721 - val_accuracy: 0.6633
# Epoch 442/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0667 - accuracy: 0.9718 - val_loss: 0.7418 - val_accuracy: 0.6833
# Epoch 443/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0715 - accuracy: 0.9703 - val_loss: 0.7910 - val_accuracy: 0.6700
# Epoch 444/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0620 - accuracy: 0.9773 - val_loss: 0.7679 - val_accuracy: 0.6767
# Epoch 445/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0448 - accuracy: 0.9802 - val_loss: 0.7456 - val_accuracy: 0.6833
# Epoch 446/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.0652 - accuracy: 0.9755 - val_loss: 0.8160 - val_accuracy: 0.6200
# Epoch 447/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0825 - accuracy: 0.9686 - val_loss: 0.7702 - val_accuracy: 0.6433
# Epoch 448/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.0870 - accuracy: 0.9652 - val_loss: 0.8086 - val_accuracy: 0.6433
# Epoch 449/500
# 26/26 [==============================] - 9s 345ms/step - loss: 0.0679 - accuracy: 0.9732 - val_loss: 0.7677 - val_accuracy: 0.6567
# Epoch 450/500
# 26/26 [==============================] - 9s 344ms/step - loss: 0.0606 - accuracy: 0.9778 - val_loss: 0.7764 - val_accuracy: 0.6300
# Epoch 451/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.0542 - accuracy: 0.9801 - val_loss: 0.8063 - val_accuracy: 0.6733
# Epoch 452/500
# 26/26 [==============================] - 9s 343ms/step - loss: 0.0645 - accuracy: 0.9750 - val_loss: 0.7819 - val_accuracy: 0.6633
# Epoch 453/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0655 - accuracy: 0.9722 - val_loss: 0.7058 - val_accuracy: 0.6733
# Epoch 454/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0510 - accuracy: 0.9812 - val_loss: 0.6973 - val_accuracy: 0.6933
# Epoch 455/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0626 - accuracy: 0.9772 - val_loss: 0.7146 - val_accuracy: 0.6533
# Epoch 456/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0785 - accuracy: 0.9698 - val_loss: 0.8653 - val_accuracy: 0.6500
# Epoch 457/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0727 - accuracy: 0.9708 - val_loss: 0.7981 - val_accuracy: 0.6467
# Epoch 458/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0779 - accuracy: 0.9723 - val_loss: 0.7926 - val_accuracy: 0.6467
# Epoch 459/500
# 26/26 [==============================] - 9s 346ms/step - loss: 0.0650 - accuracy: 0.9778 - val_loss: 0.7516 - val_accuracy: 0.6900
# Epoch 460/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0593 - accuracy: 0.9786 - val_loss: 0.8033 - val_accuracy: 0.6667
# Epoch 461/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0486 - accuracy: 0.9824 - val_loss: 0.8316 - val_accuracy: 0.6567
# Epoch 462/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0795 - accuracy: 0.9695 - val_loss: 0.8241 - val_accuracy: 0.6667
# Epoch 463/500
# 26/26 [==============================] - 9s 348ms/step - loss: 0.0653 - accuracy: 0.9789 - val_loss: 0.7260 - val_accuracy: 0.6967
# Epoch 464/500
# 26/26 [==============================] - 9s 350ms/step - loss: 0.0648 - accuracy: 0.9747 - val_loss: 0.8223 - val_accuracy: 0.6567
# Epoch 465/500
# 26/26 [==============================] - 9s 352ms/step - loss: 0.0586 - accuracy: 0.9792 - val_loss: 0.7531 - val_accuracy: 0.6833
# Epoch 466/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0627 - accuracy: 0.9811 - val_loss: 0.9752 - val_accuracy: 0.6267
# Epoch 467/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0668 - accuracy: 0.9744 - val_loss: 0.7853 - val_accuracy: 0.6600
# Epoch 468/500
# 26/26 [==============================] - 9s 347ms/step - loss: 0.0546 - accuracy: 0.9737 - val_loss: 0.7980 - val_accuracy: 0.6500
# Epoch 469/500
# 26/26 [==============================] - 9s 353ms/step - loss: 0.0625 - accuracy: 0.9754 - val_loss: 0.8579 - val_accuracy: 0.6700
# Epoch 470/500
# 26/26 [==============================] - 9s 356ms/step - loss: 0.0686 - accuracy: 0.9764 - val_loss: 0.8713 - val_accuracy: 0.6500
# Epoch 471/500
# 26/26 [==============================] - 9s 353ms/step - loss: 0.0637 - accuracy: 0.9773 - val_loss: 0.8226 - val_accuracy: 0.6633
# Epoch 472/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0561 - accuracy: 0.9788 - val_loss: 0.8486 - val_accuracy: 0.6467
# Epoch 473/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0525 - accuracy: 0.9786 - val_loss: 0.8241 - val_accuracy: 0.6367
# Epoch 474/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0740 - accuracy: 0.9729 - val_loss: 0.8795 - val_accuracy: 0.6800
# Epoch 475/500
# 26/26 [==============================] - 9s 351ms/step - loss: 0.0666 - accuracy: 0.9743 - val_loss: 0.7984 - val_accuracy: 0.6700
# Epoch 476/500
# 26/26 [==============================] - 9s 349ms/step - loss: 0.0724 - accuracy: 0.9779 - val_loss: 0.8196 - val_accuracy: 0.6533
# Epoch 477/500
# 26/26 [==============================] - 9s 353ms/step - loss: 0.0542 - accuracy: 0.9810 - val_loss: 0.8486 - val_accuracy: 0.6667
# Epoch 478/500
# 26/26 [==============================] - 9s 357ms/step - loss: 0.
# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(500)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = ['box (Class 0)', 'chevron (Class 1)', 'rounded (Class 2)']))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
#     box (Class 0)       0.28      0.69      0.40       100
# chevron (Class 1)       0.25      0.14      0.18       100
# rounded (Class 2)       0.00      0.00      0.00       100
#
#          accuracy                           0.28       300
#         macro avg       0.18      0.28      0.19       300
#      weighted avg       0.18      0.28      0.19       300
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
predictions = model.predict_classes(x_test)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_test, predictions, target_names = ['box (Class 0)', 'chevron (Class 1)', 'rounded (Class 2)']))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
#     box (Class 0)       0.30      0.73      0.43        22
# chevron (Class 1)       0.20      0.14      0.16        22
# rounded (Class 2)       0.00      0.00      0.00        24
#
#          accuracy                           0.28        68
#         macro avg       0.17      0.29      0.20        68
#      weighted avg       0.16      0.28      0.19        68
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from keras.preprocessing import image
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers[:50]]
test_image = '/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL/chevron/106.PNG'

img = image.load_img(test_image, target_size=(img_size, img_size))
img_tensor = image.img_to_array(img)
img_tensor = img_tensor.reshape(-1, img_size, img_size, 1)
# img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

layer_names = ['conv2d_1', 'activation_1', 'conv2d_2', 'activation_2', 'conv2d_5', 'activation_5']
activ_list = [activations[1], activations[3], activations[11], activations[13]]

images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activ_list):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0, :, :, col * images_per_row + row]
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image

    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='plasma')
    plt.savefig(layer_name+"_grid.jpg", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-e6248065829a> in <module>()
#       4 test_image = '/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL/chevron/106.PNG'
#       5
# ----> 6 img = image.load_img(test_image, target_size=(img_size, img_size))
#       7 img_tensor = image.img_to_array(img)
#       8 img_tensor = img_tensor.reshape(-1, img_size, img_size, 1)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     298   """
#     299   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 300                         target_size=target_size, interpolation=interpolation)
#     301
#     302
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL/chevron/106.PNG'

# %%
from keras.preprocessing import image
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers[:50]]
test_image = '/content/drive/MyDrive/Ramsey_Fold_Classification_3/TEST/chevron/download (13).jpg'

img = image.load_img(test_image, target_size=(img_size, img_size))
img_tensor = image.img_to_array(img)
img_tensor = img_tensor.reshape(-1, img_size, img_size, 1)
# img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

layer_names = ['conv2d_1', 'activation_1', 'conv2d_2', 'activation_2', 'conv2d_5', 'activation_5']
activ_list = [activations[1], activations[3], activations[11], activations[13]]

images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activ_list):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0, :, :, col * images_per_row + row]
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image

    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='plasma')
    plt.savefig(layer_name+"_grid.jpg", bbox_inches='tight')
