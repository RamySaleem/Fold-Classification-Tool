# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from keras.datasets import cifar10
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping

# %%
import glob
import os
import torch
import tarfile
import imageio
import tarfile
import pandas as pd
import numpy as np
import torchvision
from PIL import Image
import seaborn as sns
import torchvision.models as models
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torchvision.transforms as T
from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid
import matplotlib
# %matplotlib inline
import torchvision.transforms as transforms
import torchvision.transforms as tt
from torchvision.datasets.utils import download_url
from torch.utils.data import Dataset, random_split, DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
import torch.nn as nn
import torch.nn.functional as F

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2

# %%
labels = ['chevron', 'rounded']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
train = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TRAIN")
test = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TEST")
val = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   from ipykernel import kernelapp as app

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("chevron")
    # elif(i[1] == 1):
    #     l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in val:
    if(i[1] == 0):
        l.append("chevron")
    # elif(i[1] == 1):
    #     l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in test:
    if(i[1] == 0):
        l.append("box")
    elif(i[1] == 1):
        l.append("Chevron")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[100][0])
plt.title(labels[train[100][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1000][0])
plt.title(labels[train[1000][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1500][0])
plt.title(labels[train[1500][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[800][0])
plt.title(labels[train[800][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1500][0])
plt.title(labels[train[1500][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)
datagen.fit(x_val)

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(512 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.3))
model.add(Dense(units = 3 , activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,654,019
# Trainable params: 2,654,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "Adam" , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])

# %%
lr=0.000001

history = model.fit(datagen.flow(x_train,y_train, batch_size=64),
                    epochs = 80 , 
                    validation_data = datagen.flow(x_val, y_val))
# Out:
# Epoch 1/80
# 30/30 [==============================] - 7s 154ms/step - loss: 0.8307 - accuracy: 0.4864 - val_loss: 0.7417 - val_accuracy: 0.5000
# Epoch 2/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.7208 - accuracy: 0.4795 - val_loss: 0.7098 - val_accuracy: 0.5000
# Epoch 3/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.7021 - accuracy: 0.5066 - val_loss: 0.6859 - val_accuracy: 0.5229
# Epoch 4/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.6741 - accuracy: 0.5693 - val_loss: 0.6365 - val_accuracy: 0.7312
# Epoch 5/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.5799 - accuracy: 0.7059 - val_loss: 0.6244 - val_accuracy: 0.7229
# Epoch 6/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.5229 - accuracy: 0.7571 - val_loss: 0.4771 - val_accuracy: 0.8500
# Epoch 7/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.4095 - accuracy: 0.8226 - val_loss: 0.3381 - val_accuracy: 0.8458
# Epoch 8/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.3386 - accuracy: 0.8557 - val_loss: 0.3450 - val_accuracy: 0.8667
# Epoch 9/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.3233 - accuracy: 0.8559 - val_loss: 0.2768 - val_accuracy: 0.8854
# Epoch 10/80
# 30/30 [==============================] - 4s 146ms/step - loss: 0.2839 - accuracy: 0.8785 - val_loss: 0.2524 - val_accuracy: 0.9000
# Epoch 11/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.2478 - accuracy: 0.8948 - val_loss: 0.2315 - val_accuracy: 0.9354
# Epoch 12/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.2072 - accuracy: 0.9307 - val_loss: 0.1933 - val_accuracy: 0.9417
# Epoch 13/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1796 - accuracy: 0.9306 - val_loss: 0.1535 - val_accuracy: 0.9396
# Epoch 14/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1690 - accuracy: 0.9300 - val_loss: 0.1481 - val_accuracy: 0.9646
# Epoch 15/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1604 - accuracy: 0.9467 - val_loss: 0.1143 - val_accuracy: 0.9625
# Epoch 16/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1694 - accuracy: 0.9338 - val_loss: 0.1472 - val_accuracy: 0.9521
# Epoch 17/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1422 - accuracy: 0.9415 - val_loss: 0.1289 - val_accuracy: 0.9563
# Epoch 18/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.1248 - accuracy: 0.9544 - val_loss: 0.1176 - val_accuracy: 0.9563
# Epoch 19/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1539 - accuracy: 0.9415 - val_loss: 0.1072 - val_accuracy: 0.9625
# Epoch 20/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1183 - accuracy: 0.9588 - val_loss: 0.1071 - val_accuracy: 0.9646
# Epoch 21/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1116 - accuracy: 0.9563 - val_loss: 0.1166 - val_accuracy: 0.9604
# Epoch 22/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1072 - accuracy: 0.9550 - val_loss: 0.0951 - val_accuracy: 0.9729
# Epoch 23/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0784 - accuracy: 0.9713 - val_loss: 0.1036 - val_accuracy: 0.9667
# Epoch 24/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1259 - accuracy: 0.9523 - val_loss: 0.0993 - val_accuracy: 0.9688
# Epoch 25/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1003 - accuracy: 0.9650 - val_loss: 0.0963 - val_accuracy: 0.9646
# Epoch 26/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1139 - accuracy: 0.9591 - val_loss: 0.1258 - val_accuracy: 0.9646
# Epoch 27/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0902 - accuracy: 0.9690 - val_loss: 0.0736 - val_accuracy: 0.9729
# Epoch 28/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0774 - accuracy: 0.9747 - val_loss: 0.0501 - val_accuracy: 0.9854
# Epoch 29/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0928 - accuracy: 0.9674 - val_loss: 0.1015 - val_accuracy: 0.9604
# Epoch 30/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0859 - accuracy: 0.9681 - val_loss: 0.0622 - val_accuracy: 0.9792
# Epoch 31/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0916 - accuracy: 0.9663 - val_loss: 0.0686 - val_accuracy: 0.9750
# Epoch 32/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0822 - accuracy: 0.9770 - val_loss: 0.0648 - val_accuracy: 0.9812
# Epoch 33/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0871 - accuracy: 0.9663 - val_loss: 0.0680 - val_accuracy: 0.9771
# Epoch 34/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0861 - accuracy: 0.9634 - val_loss: 0.0568 - val_accuracy: 0.9729
# Epoch 35/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0813 - accuracy: 0.9704 - val_loss: 0.0435 - val_accuracy: 0.9833
# Epoch 36/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0784 - accuracy: 0.9683 - val_loss: 0.0807 - val_accuracy: 0.9688
# Epoch 37/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0829 - accuracy: 0.9656 - val_loss: 0.0654 - val_accuracy: 0.9792
# Epoch 38/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0781 - accuracy: 0.9668 - val_loss: 0.0606 - val_accuracy: 0.9812
# Epoch 39/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0795 - accuracy: 0.9715 - val_loss: 0.0689 - val_accuracy: 0.9729
# Epoch 40/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0637 - accuracy: 0.9746 - val_loss: 0.0501 - val_accuracy: 0.9812
# Epoch 41/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0828 - accuracy: 0.9680 - val_loss: 0.0644 - val_accuracy: 0.9792
# Epoch 42/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0684 - accuracy: 0.9743 - val_loss: 0.0634 - val_accuracy: 0.9729
# Epoch 43/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0760 - accuracy: 0.9735 - val_loss: 0.0879 - val_accuracy: 0.9604
# Epoch 44/80
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0783 - accuracy: 0.9699 - val_loss: 0.0740 - val_accuracy: 0.9708
# Epoch 45/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0753 - accuracy: 0.9685 - val_loss: 0.0557 - val_accuracy: 0.9771
# Epoch 46/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0674 - accuracy: 0.9717 - val_loss: 0.0605 - val_accuracy: 0.9854
# Epoch 47/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0805 - accuracy: 0.9630 - val_loss: 0.0509 - val_accuracy: 0.9854
# Epoch 48/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0647 - accuracy: 0.9770 - val_loss: 0.0683 - val_accuracy: 0.9750
# Epoch 49/80
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0610 - accuracy: 0.9782 - val_loss: 0.0506 - val_accuracy: 0.9812
# Epoch 50/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0571 - accuracy: 0.9787 - val_loss: 0.1040 - val_accuracy: 0.9625
# Epoch 51/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0858 - accuracy: 0.9590 - val_loss: 0.0540 - val_accuracy: 0.9750
# Epoch 52/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0761 - accuracy: 0.9724 - val_loss: 0.0427 - val_accuracy: 0.9854
# Epoch 53/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0577 - accuracy: 0.9765 - val_loss: 0.0678 - val_accuracy: 0.9812
# Epoch 54/80
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0595 - accuracy: 0.9805 - val_loss: 0.0598 - val_accuracy: 0.9792
# Epoch 55/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0659 - accuracy: 0.9751 - val_loss: 0.0770 - val_accuracy: 0.9729
# Epoch 56/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0659 - accuracy: 0.9698 - val_loss: 0.0579 - val_accuracy: 0.9812
# Epoch 57/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0688 - accuracy: 0.9698 - val_loss: 0.0475 - val_accuracy: 0.9812
# Epoch 58/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0684 - accuracy: 0.9759 - val_loss: 0.0693 - val_accuracy: 0.9771
# Epoch 59/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0770 - accuracy: 0.9703 - val_loss: 0.0558 - val_accuracy: 0.9833
# Epoch 60/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1014 - accuracy: 0.9593 - val_loss: 0.0580 - val_accuracy: 0.9792
# Epoch 61/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0542 - accuracy: 0.9757 - val_loss: 0.0534 - val_accuracy: 0.9792
# Epoch 62/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0613 - accuracy: 0.9791 - val_loss: 0.0537 - val_accuracy: 0.9833
# Epoch 63/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0851 - accuracy: 0.9658 - val_loss: 0.0606 - val_accuracy: 0.9771
# Epoch 64/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0565 - accuracy: 0.9726 - val_loss: 0.0747 - val_accuracy: 0.9812
# Epoch 65/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0671 - accuracy: 0.9706 - val_loss: 0.0616 - val_accuracy: 0.9812
# Epoch 66/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0669 - accuracy: 0.9728 - val_loss: 0.0734 - val_accuracy: 0.9708
# Epoch 67/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0669 - accuracy: 0.9717 - val_loss: 0.0551 - val_accuracy: 0.9750
# Epoch 68/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0592 - accuracy: 0.9769 - val_loss: 0.0404 - val_accuracy: 0.9812
# Epoch 69/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0605 - accuracy: 0.9787 - val_loss: 0.0613 - val_accuracy: 0.9833
# Epoch 70/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0585 - accuracy: 0.9742 - val_loss: 0.0806 - val_accuracy: 0.9771
# Epoch 71/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0616 - accuracy: 0.9756 - val_loss: 0.0583 - val_accuracy: 0.9750
# Epoch 72/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0500 - accuracy: 0.9756 - val_loss: 0.0649 - val_accuracy: 0.9812
# Epoch 73/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0575 - accuracy: 0.9788 - val_loss: 0.0430 - val_accuracy: 0.9833
# Epoch 74/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0517 - accuracy: 0.9766 - val_loss: 0.0406 - val_accuracy: 0.9854
# Epoch 75/80
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0542 - accuracy: 0.9773 - val_loss: 0.0510 - val_accuracy: 0.9854
# Epoch 76/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0449 - accuracy: 0.9856 - val_loss: 0.0652 - val_accuracy: 0.9771
# Epoch 77/80
# 30/30 [==============================] - 4s 148ms/step - loss: 0.0653 - accuracy: 0.9743 - val_loss: 0.0486 - val_accuracy: 0.9854
# Epoch 78/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0425 - accuracy: 0.9806 - val_loss: 0.0511 - val_accuracy: 0.9792
# Epoch 79/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0607 - accuracy: 0.9838 - val_loss: 0.0565 - val_accuracy: 0.9792
# Epoch 80/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0516 - accuracy: 0.9767 - val_loss: 0.0392 - val_accuracy: 0.9875

# %%
predictions = model.predict_classes(x_test)
predictions = predictions.reshape(1,-1)[0]
cm= confusion_matrix(y_test,predictions)

print(classification_report(y_test, predictions, target_names = ['rounded (Class 1)', 'chevron (Class 0)']))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
# rounded (Class 1)       0.61      1.00      0.76        22
# chevron (Class 0)       1.00      0.36      0.53        22
#
#          accuracy                           0.68        44
#         macro avg       0.81      0.68      0.65        44
#      weighted avg       0.81      0.68      0.65        44

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(80)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = ['rouned (Class 1)', 'chevron (Class 0)']))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
#  rouned (Class 1)       0.99      0.98      0.99       240
# chevron (Class 0)       0.98      0.99      0.99       240
#
#          accuracy                           0.99       480
#         macro avg       0.99      0.99      0.99       480
#      weighted avg       0.99      0.99      0.99       480

# %%
predictions = model.predict_classes(x_test)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_test, predictions, target_names = ['rouned (Class 1)', 'chevron (Class 0)']))
# Out:
#                    precision    recall  f1-score   support
#
#  rouned (Class 1)       0.61      1.00      0.76        22
# chevron (Class 0)       1.00      0.36      0.53        22
#
#          accuracy                           0.68        44
#         macro avg       0.81      0.68      0.65        44
#      weighted avg       0.81      0.68      0.65        44
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from keras.preprocessing import image
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers[:50]]
test_image = '/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL/chevron/106.PNG'

img = image.load_img(test_image, target_size=(img_size, img_size))
img_tensor = image.img_to_array(img)
img_tensor = img_tensor.reshape(-1, img_size, img_size, 1)
# img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

layer_names = ['conv2d_1', 'activation_1', 'conv2d_2', 'activation_2', 'conv2d_5', 'activation_5']
activ_list = [activations[1], activations[3], activations[11], activations[13]]

images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activ_list):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0, :, :, col * images_per_row + row]
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image

    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='plasma')
    plt.savefig(layer_name+"_grid.jpg", bbox_inches='tight')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide

# %%
from keras.preprocessing import image
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers[:50]]
test_image = '/content/drive/MyDrive/Ramsey_Fold_Classification_3/TEST/chevron/download (13).jpg'

img = image.load_img(test_image, target_size=(img_size, img_size))
img_tensor = image.img_to_array(img)
img_tensor = img_tensor.reshape(-1, img_size, img_size, 1)
# img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

layer_names = ['conv2d_1', 'activation_1', 'conv2d_2', 'activation_2', 'conv2d_5', 'activation_5']
activ_list = [activations[1], activations[3], activations[11], activations[13]]

images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activ_list):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0, :, :, col * images_per_row + row]
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image

    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='plasma')
    plt.savefig(layer_name+"_grid.jpg", bbox_inches='tight')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
