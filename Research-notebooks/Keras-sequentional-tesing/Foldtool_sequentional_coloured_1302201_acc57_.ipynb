# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from keras.datasets import cifar10
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping

# %%
import glob
import os
import torch
import tarfile
import imageio
import tarfile
import pandas as pd
import numpy as np
import torchvision
from PIL import Image
import seaborn as sns
import torchvision.models as models
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torchvision.transforms as T
from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid
import matplotlib
# %matplotlib inline
import torchvision.transforms as transforms
import torchvision.transforms as tt
from torchvision.datasets.utils import download_url
from torch.utils.data import Dataset, random_split, DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
import torch.nn as nn
import torch.nn.functional as F

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2

# %%
labels = ['chevron', 'rounded']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
train = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TRAIN")
test = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TEST")
val = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   from ipykernel import kernelapp as app

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("chevron")
    # elif(i[1] == 1):
    #     l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in val:
    if(i[1] == 0):
        l.append("chevron")
    # elif(i[1] == 1):
    #     l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in test:
    if(i[1] == 0):
        l.append("box")
    elif(i[1] == 1):
        l.append("Chevron")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[100][0])
plt.title(labels[train[100][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1000][0])
plt.title(labels[train[1000][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1500][0])
plt.title(labels[train[1500][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[800][0])
plt.title(labels[train[800][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1500][0])
plt.title(labels[train[1500][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(512 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.3))
model.add(Dense(units = 3 , activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,654,019
# Trainable params: 2,654,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "Adam" , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])

# %%
lr=0.000001

history = model.fit(datagen.flow(x_train,y_train, batch_size=64),
                    epochs = 80 , 
                    validation_data = datagen.flow(x_val, y_val))
# Out:
# Epoch 1/80
# 30/30 [==============================] - 12s 148ms/step - loss: 0.8124 - accuracy: 0.4992 - val_loss: 0.7379 - val_accuracy: 0.5000
# Epoch 2/80
# 30/30 [==============================] - 4s 139ms/step - loss: 0.7070 - accuracy: 0.4907 - val_loss: 0.7172 - val_accuracy: 0.5000
# Epoch 3/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.7002 - accuracy: 0.5155 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 4/80
# 30/30 [==============================] - 5s 167ms/step - loss: 0.6798 - accuracy: 0.5605 - val_loss: 0.6188 - val_accuracy: 0.7479
# Epoch 5/80
# 30/30 [==============================] - 4s 146ms/step - loss: 0.5645 - accuracy: 0.7191 - val_loss: 0.4919 - val_accuracy: 0.8167
# Epoch 6/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.4431 - accuracy: 0.8097 - val_loss: 0.4609 - val_accuracy: 0.8542
# Epoch 7/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.4413 - accuracy: 0.8063 - val_loss: 0.4200 - val_accuracy: 0.8667
# Epoch 8/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.3684 - accuracy: 0.8481 - val_loss: 0.3499 - val_accuracy: 0.8708
# Epoch 9/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.3295 - accuracy: 0.8582 - val_loss: 0.3845 - val_accuracy: 0.8854
# Epoch 10/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.3066 - accuracy: 0.8645 - val_loss: 0.3140 - val_accuracy: 0.9187
# Epoch 11/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.2657 - accuracy: 0.8912 - val_loss: 0.2465 - val_accuracy: 0.9250
# Epoch 12/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.2469 - accuracy: 0.9009 - val_loss: 0.2042 - val_accuracy: 0.9396
# Epoch 13/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.2093 - accuracy: 0.9168 - val_loss: 0.1375 - val_accuracy: 0.9438
# Epoch 14/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.2100 - accuracy: 0.9187 - val_loss: 0.1451 - val_accuracy: 0.9458
# Epoch 15/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1551 - accuracy: 0.9393 - val_loss: 0.1705 - val_accuracy: 0.9479
# Epoch 16/80
# 30/30 [==============================] - 4s 139ms/step - loss: 0.1655 - accuracy: 0.9360 - val_loss: 0.1543 - val_accuracy: 0.9688
# Epoch 17/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.1561 - accuracy: 0.9326 - val_loss: 0.1572 - val_accuracy: 0.9479
# Epoch 18/80
# 30/30 [==============================] - 5s 165ms/step - loss: 0.1257 - accuracy: 0.9486 - val_loss: 0.1338 - val_accuracy: 0.9646
# Epoch 19/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1356 - accuracy: 0.9480 - val_loss: 0.1121 - val_accuracy: 0.9688
# Epoch 20/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1465 - accuracy: 0.9418 - val_loss: 0.1019 - val_accuracy: 0.9667
# Epoch 21/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1155 - accuracy: 0.9504 - val_loss: 0.1257 - val_accuracy: 0.9708
# Epoch 22/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1190 - accuracy: 0.9596 - val_loss: 0.0748 - val_accuracy: 0.9854
# Epoch 23/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1126 - accuracy: 0.9578 - val_loss: 0.1310 - val_accuracy: 0.9667
# Epoch 24/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1264 - accuracy: 0.9515 - val_loss: 0.0915 - val_accuracy: 0.9729
# Epoch 25/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1061 - accuracy: 0.9601 - val_loss: 0.1130 - val_accuracy: 0.9688
# Epoch 26/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1094 - accuracy: 0.9606 - val_loss: 0.0891 - val_accuracy: 0.9667
# Epoch 27/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0932 - accuracy: 0.9615 - val_loss: 0.0859 - val_accuracy: 0.9708
# Epoch 28/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1099 - accuracy: 0.9552 - val_loss: 0.0742 - val_accuracy: 0.9729
# Epoch 29/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1054 - accuracy: 0.9607 - val_loss: 0.1262 - val_accuracy: 0.9750
# Epoch 30/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1145 - accuracy: 0.9648 - val_loss: 0.1333 - val_accuracy: 0.9479
# Epoch 31/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1053 - accuracy: 0.9667 - val_loss: 0.0799 - val_accuracy: 0.9792
# Epoch 32/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0731 - accuracy: 0.9763 - val_loss: 0.0773 - val_accuracy: 0.9771
# Epoch 33/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1190 - accuracy: 0.9647 - val_loss: 0.0827 - val_accuracy: 0.9708
# Epoch 34/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0614 - accuracy: 0.9773 - val_loss: 0.0772 - val_accuracy: 0.9750
# Epoch 35/80
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0840 - accuracy: 0.9732 - val_loss: 0.0693 - val_accuracy: 0.9792
# Epoch 36/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0727 - accuracy: 0.9777 - val_loss: 0.0687 - val_accuracy: 0.9667
# Epoch 37/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0681 - accuracy: 0.9694 - val_loss: 0.0654 - val_accuracy: 0.9771
# Epoch 38/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0700 - accuracy: 0.9701 - val_loss: 0.0945 - val_accuracy: 0.9625
# Epoch 39/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0694 - accuracy: 0.9768 - val_loss: 0.0748 - val_accuracy: 0.9771
# Epoch 40/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0783 - accuracy: 0.9726 - val_loss: 0.0801 - val_accuracy: 0.9708
# Epoch 41/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0703 - accuracy: 0.9754 - val_loss: 0.0873 - val_accuracy: 0.9833
# Epoch 42/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0720 - accuracy: 0.9737 - val_loss: 0.0621 - val_accuracy: 0.9771
# Epoch 43/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0620 - accuracy: 0.9750 - val_loss: 0.0997 - val_accuracy: 0.9563
# Epoch 44/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1015 - accuracy: 0.9612 - val_loss: 0.0768 - val_accuracy: 0.9750
# Epoch 45/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0874 - accuracy: 0.9623 - val_loss: 0.0644 - val_accuracy: 0.9750
# Epoch 46/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0879 - accuracy: 0.9675 - val_loss: 0.0709 - val_accuracy: 0.9729
# Epoch 47/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0653 - accuracy: 0.9699 - val_loss: 0.0690 - val_accuracy: 0.9729
# Epoch 48/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0659 - accuracy: 0.9719 - val_loss: 0.0722 - val_accuracy: 0.9708
# Epoch 49/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0689 - accuracy: 0.9702 - val_loss: 0.0708 - val_accuracy: 0.9750
# Epoch 50/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0721 - accuracy: 0.9718 - val_loss: 0.0823 - val_accuracy: 0.9729
# Epoch 51/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0778 - accuracy: 0.9722 - val_loss: 0.0701 - val_accuracy: 0.9771
# Epoch 52/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0804 - accuracy: 0.9734 - val_loss: 0.0414 - val_accuracy: 0.9875
# Epoch 53/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0627 - accuracy: 0.9774 - val_loss: 0.0787 - val_accuracy: 0.9750
# Epoch 54/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0710 - accuracy: 0.9723 - val_loss: 0.0775 - val_accuracy: 0.9750
# Epoch 55/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0580 - accuracy: 0.9753 - val_loss: 0.0627 - val_accuracy: 0.9812
# Epoch 56/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0576 - accuracy: 0.9775 - val_loss: 0.0676 - val_accuracy: 0.9729
# Epoch 57/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0734 - accuracy: 0.9753 - val_loss: 0.0740 - val_accuracy: 0.9750
# Epoch 58/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0651 - accuracy: 0.9770 - val_loss: 0.0814 - val_accuracy: 0.9729
# Epoch 59/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0863 - accuracy: 0.9667 - val_loss: 0.0640 - val_accuracy: 0.9833
# Epoch 60/80
# 30/30 [==============================] - 5s 171ms/step - loss: 0.0720 - accuracy: 0.9723 - val_loss: 0.0862 - val_accuracy: 0.9688
# Epoch 61/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0776 - accuracy: 0.9768 - val_loss: 0.0580 - val_accuracy: 0.9792
# Epoch 62/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0503 - accuracy: 0.9769 - val_loss: 0.0717 - val_accuracy: 0.9729
# Epoch 63/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0540 - accuracy: 0.9820 - val_loss: 0.0946 - val_accuracy: 0.9688
# Epoch 64/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0756 - accuracy: 0.9757 - val_loss: 0.0973 - val_accuracy: 0.9604
# Epoch 65/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0677 - accuracy: 0.9703 - val_loss: 0.0546 - val_accuracy: 0.9854
# Epoch 66/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0666 - accuracy: 0.9789 - val_loss: 0.0610 - val_accuracy: 0.9729
# Epoch 67/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0640 - accuracy: 0.9807 - val_loss: 0.0619 - val_accuracy: 0.9688
# Epoch 68/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0499 - accuracy: 0.9817 - val_loss: 0.0762 - val_accuracy: 0.9771
# Epoch 69/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0442 - accuracy: 0.9863 - val_loss: 0.0673 - val_accuracy: 0.9750
# Epoch 70/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0592 - accuracy: 0.9785 - val_loss: 0.0650 - val_accuracy: 0.9792
# Epoch 71/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0554 - accuracy: 0.9775 - val_loss: 0.0557 - val_accuracy: 0.9792
# Epoch 72/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0631 - accuracy: 0.9708 - val_loss: 0.0723 - val_accuracy: 0.9771
# Epoch 73/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0577 - accuracy: 0.9773 - val_loss: 0.0877 - val_accuracy: 0.9750
# Epoch 74/80
# 30/30 [==============================] - 5s 165ms/step - loss: 0.0636 - accuracy: 0.9750 - val_loss: 0.0621 - val_accuracy: 0.9854
# Epoch 75/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0652 - accuracy: 0.9729 - val_loss: 0.0591 - val_accuracy: 0.9792
# Epoch 76/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0500 - accuracy: 0.9762 - val_loss: 0.0644 - val_accuracy: 0.9688
# Epoch 77/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0507 - accuracy: 0.9788 - val_loss: 0.0563 - val_accuracy: 0.9771
# Epoch 78/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0543 - accuracy: 0.9804 - val_loss: 0.0717 - val_accuracy: 0.9812
# Epoch 79/80
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0448 - accuracy: 0.9832 - val_loss: 0.0684 - val_accuracy: 0.9750
# Epoch 80/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0497 - accuracy: 0.9841 - val_loss: 0.0565 - val_accuracy: 0.9812

# %%
predictions = model.predict_classes(x_test)
predictions = predictions.reshape(1,-1)[0]
cm= confusion_matrix(y_test,predictions)

print(classification_report(y_test, predictions, target_names = ['rounded (Class 1)', 'chevron (Class 0)']))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
# rounded (Class 1)       0.56      0.64      0.60        22
# chevron (Class 0)       0.58      0.50      0.54        22
#
#          accuracy                           0.57        44
#         macro avg       0.57      0.57      0.57        44
#      weighted avg       0.57      0.57      0.57        44

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(80)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = ['rouned (Class 1)', 'chevron (Class 0)']))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
#  rouned (Class 1)       0.99      0.99      0.99       240
# chevron (Class 0)       0.99      0.99      0.99       240
#
#          accuracy                           0.99       480
#         macro avg       0.99      0.99      0.99       480
#      weighted avg       0.99      0.99      0.99       480

# %%
predictions = model.predict_classes(x_test)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_test, predictions, target_names = ['rouned (Class 1)', 'chevron (Class 0)']))
# Out:
#                    precision    recall  f1-score   support
#
#  rouned (Class 1)       0.56      0.64      0.60        22
# chevron (Class 0)       0.58      0.50      0.54        22
#
#          accuracy                           0.57        44
#         macro avg       0.57      0.57      0.57        44
#      weighted avg       0.57      0.57      0.57        44
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
