# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from keras.datasets import cifar10
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping

# %%
import glob
import os
import torch
import tarfile
import imageio
import tarfile
import pandas as pd
import numpy as np
import torchvision
from PIL import Image
import seaborn as sns
import torchvision.models as models
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torchvision.transforms as T
from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid
import matplotlib
# %matplotlib inline
import torchvision.transforms as transforms
import torchvision.transforms as tt
from torchvision.datasets.utils import download_url
from torch.utils.data import Dataset, random_split, DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
import torch.nn as nn
import torch.nn.functional as F

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2

# %%
labels = ['chevron', 'rounded']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
train = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TRAIN")
test = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/TEST")
val = get_data("/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   from ipykernel import kernelapp as app

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("chevron")
    # elif(i[1] == 1):
    #     l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in val:
    if(i[1] == 0):
        l.append("chevron")
    # elif(i[1] == 1):
    #     l.append("box")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
l = []
for i in test:
    if(i[1] == 0):
        l.append("box")
    elif(i[1] == 1):
        l.append("Chevron")
    else:
        l.append("rounded")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[100][0])
plt.title(labels[train[100][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1000][0])
plt.title(labels[train[1000][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1500][0])
plt.title(labels[train[1500][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[800][0])
plt.title(labels[train[800][1]])
# Out:
# Text(0.5, 1.0, 'chevron')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1500][0])
plt.title(labels[train[1500][1]])
# Out:
# Text(0.5, 1.0, 'rounded')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)
datagen.fit(x_test)

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(BatchNormalization())
model.add(MaxPool2D((2,2)))

model.add(Conv2D(512 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.3))
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.3))
model.add(Dense(units = 3 , activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,654,019
# Trainable params: 2,654,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "Adam" , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])

# %%
lr=0.000001

history = model.fit(datagen.flow(x_train,y_train, batch_size=64),
                    epochs = 80 , 
                    validation_data = datagen.flow(x_val, y_val))
# Out:
# Epoch 1/80
# 30/30 [==============================] - 7s 155ms/step - loss: 0.7912 - accuracy: 0.5027 - val_loss: 0.7193 - val_accuracy: 0.5000
# Epoch 2/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.7057 - accuracy: 0.4932 - val_loss: 0.7068 - val_accuracy: 0.5000
# Epoch 3/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.7000 - accuracy: 0.5013 - val_loss: 0.7050 - val_accuracy: 0.5000
# Epoch 4/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.6969 - accuracy: 0.5079 - val_loss: 0.6950 - val_accuracy: 0.5000
# Epoch 5/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.6785 - accuracy: 0.5646 - val_loss: 0.5070 - val_accuracy: 0.7708
# Epoch 6/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.5496 - accuracy: 0.7197 - val_loss: 0.5004 - val_accuracy: 0.7937
# Epoch 7/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.4075 - accuracy: 0.8120 - val_loss: 0.4059 - val_accuracy: 0.8792
# Epoch 8/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.3647 - accuracy: 0.8418 - val_loss: 0.3474 - val_accuracy: 0.9146
# Epoch 9/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.3013 - accuracy: 0.8676 - val_loss: 0.3522 - val_accuracy: 0.8938
# Epoch 10/80
# 30/30 [==============================] - 4s 147ms/step - loss: 0.2987 - accuracy: 0.8820 - val_loss: 0.2726 - val_accuracy: 0.9292
# Epoch 11/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.2459 - accuracy: 0.9086 - val_loss: 0.2375 - val_accuracy: 0.9604
# Epoch 12/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.2266 - accuracy: 0.9066 - val_loss: 0.2386 - val_accuracy: 0.9542
# Epoch 13/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1797 - accuracy: 0.9332 - val_loss: 0.1993 - val_accuracy: 0.9646
# Epoch 14/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1726 - accuracy: 0.9317 - val_loss: 0.1579 - val_accuracy: 0.9542
# Epoch 15/80
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1562 - accuracy: 0.9398 - val_loss: 0.2323 - val_accuracy: 0.9500
# Epoch 16/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1612 - accuracy: 0.9376 - val_loss: 0.1643 - val_accuracy: 0.9625
# Epoch 17/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1533 - accuracy: 0.9398 - val_loss: 0.1725 - val_accuracy: 0.9500
# Epoch 18/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1636 - accuracy: 0.9395 - val_loss: 0.1337 - val_accuracy: 0.9729
# Epoch 19/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.1303 - accuracy: 0.9438 - val_loss: 0.1150 - val_accuracy: 0.9479
# Epoch 20/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1208 - accuracy: 0.9540 - val_loss: 0.1856 - val_accuracy: 0.9479
# Epoch 21/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1367 - accuracy: 0.9510 - val_loss: 0.2016 - val_accuracy: 0.9563
# Epoch 22/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1363 - accuracy: 0.9467 - val_loss: 0.1189 - val_accuracy: 0.9708
# Epoch 23/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.1139 - accuracy: 0.9580 - val_loss: 0.1367 - val_accuracy: 0.9688
# Epoch 24/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.1144 - accuracy: 0.9612 - val_loss: 0.0821 - val_accuracy: 0.9812
# Epoch 25/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.1312 - accuracy: 0.9551 - val_loss: 0.0962 - val_accuracy: 0.9667
# Epoch 26/80
# 30/30 [==============================] - 4s 146ms/step - loss: 0.1056 - accuracy: 0.9619 - val_loss: 0.1067 - val_accuracy: 0.9625
# Epoch 27/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0986 - accuracy: 0.9577 - val_loss: 0.0774 - val_accuracy: 0.9771
# Epoch 28/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0876 - accuracy: 0.9665 - val_loss: 0.1168 - val_accuracy: 0.9729
# Epoch 29/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.1010 - accuracy: 0.9622 - val_loss: 0.0993 - val_accuracy: 0.9625
# Epoch 30/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0895 - accuracy: 0.9705 - val_loss: 0.0833 - val_accuracy: 0.9792
# Epoch 31/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0796 - accuracy: 0.9690 - val_loss: 0.0602 - val_accuracy: 0.9771
# Epoch 32/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0866 - accuracy: 0.9667 - val_loss: 0.0968 - val_accuracy: 0.9833
# Epoch 33/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0851 - accuracy: 0.9705 - val_loss: 0.0897 - val_accuracy: 0.9729
# Epoch 34/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0794 - accuracy: 0.9749 - val_loss: 0.1054 - val_accuracy: 0.9625
# Epoch 35/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.1062 - accuracy: 0.9665 - val_loss: 0.0661 - val_accuracy: 0.9833
# Epoch 36/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0823 - accuracy: 0.9687 - val_loss: 0.0646 - val_accuracy: 0.9792
# Epoch 37/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0917 - accuracy: 0.9604 - val_loss: 0.0657 - val_accuracy: 0.9688
# Epoch 38/80
# 30/30 [==============================] - 4s 146ms/step - loss: 0.0745 - accuracy: 0.9742 - val_loss: 0.0975 - val_accuracy: 0.9833
# Epoch 39/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0823 - accuracy: 0.9667 - val_loss: 0.0868 - val_accuracy: 0.9750
# Epoch 40/80
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0842 - accuracy: 0.9717 - val_loss: 0.0654 - val_accuracy: 0.9833
# Epoch 41/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0800 - accuracy: 0.9698 - val_loss: 0.0720 - val_accuracy: 0.9750
# Epoch 42/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0687 - accuracy: 0.9765 - val_loss: 0.0861 - val_accuracy: 0.9729
# Epoch 43/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0826 - accuracy: 0.9735 - val_loss: 0.0667 - val_accuracy: 0.9833
# Epoch 44/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0794 - accuracy: 0.9713 - val_loss: 0.0755 - val_accuracy: 0.9854
# Epoch 45/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0715 - accuracy: 0.9702 - val_loss: 0.0642 - val_accuracy: 0.9812
# Epoch 46/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0739 - accuracy: 0.9729 - val_loss: 0.0745 - val_accuracy: 0.9812
# Epoch 47/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0840 - accuracy: 0.9693 - val_loss: 0.0723 - val_accuracy: 0.9771
# Epoch 48/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0628 - accuracy: 0.9801 - val_loss: 0.0790 - val_accuracy: 0.9812
# Epoch 49/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0671 - accuracy: 0.9764 - val_loss: 0.0782 - val_accuracy: 0.9688
# Epoch 50/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0660 - accuracy: 0.9747 - val_loss: 0.0642 - val_accuracy: 0.9792
# Epoch 51/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0674 - accuracy: 0.9763 - val_loss: 0.0635 - val_accuracy: 0.9771
# Epoch 52/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0588 - accuracy: 0.9770 - val_loss: 0.0833 - val_accuracy: 0.9729
# Epoch 53/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0671 - accuracy: 0.9769 - val_loss: 0.1305 - val_accuracy: 0.9479
# Epoch 54/80
# 30/30 [==============================] - 4s 149ms/step - loss: 0.1046 - accuracy: 0.9604 - val_loss: 0.0876 - val_accuracy: 0.9729
# Epoch 55/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0632 - accuracy: 0.9746 - val_loss: 0.0713 - val_accuracy: 0.9812
# Epoch 56/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0639 - accuracy: 0.9741 - val_loss: 0.0760 - val_accuracy: 0.9771
# Epoch 57/80
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0645 - accuracy: 0.9733 - val_loss: 0.0658 - val_accuracy: 0.9729
# Epoch 58/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0484 - accuracy: 0.9854 - val_loss: 0.0714 - val_accuracy: 0.9708
# Epoch 59/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0734 - accuracy: 0.9706 - val_loss: 0.0592 - val_accuracy: 0.9729
# Epoch 60/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0653 - accuracy: 0.9779 - val_loss: 0.0536 - val_accuracy: 0.9833
# Epoch 61/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0672 - accuracy: 0.9728 - val_loss: 0.0624 - val_accuracy: 0.9792
# Epoch 62/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0819 - accuracy: 0.9704 - val_loss: 0.0724 - val_accuracy: 0.9771
# Epoch 63/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0696 - accuracy: 0.9764 - val_loss: 0.0577 - val_accuracy: 0.9771
# Epoch 64/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0481 - accuracy: 0.9833 - val_loss: 0.0679 - val_accuracy: 0.9771
# Epoch 65/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0525 - accuracy: 0.9782 - val_loss: 0.0547 - val_accuracy: 0.9833
# Epoch 66/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0608 - accuracy: 0.9753 - val_loss: 0.0787 - val_accuracy: 0.9708
# Epoch 67/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0592 - accuracy: 0.9779 - val_loss: 0.0720 - val_accuracy: 0.9812
# Epoch 68/80
# 30/30 [==============================] - 4s 146ms/step - loss: 0.0597 - accuracy: 0.9737 - val_loss: 0.0883 - val_accuracy: 0.9750
# Epoch 69/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0917 - accuracy: 0.9613 - val_loss: 0.0881 - val_accuracy: 0.9688
# Epoch 70/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0588 - accuracy: 0.9789 - val_loss: 0.0666 - val_accuracy: 0.9771
# Epoch 71/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0594 - accuracy: 0.9772 - val_loss: 0.0573 - val_accuracy: 0.9792
# Epoch 72/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0667 - accuracy: 0.9752 - val_loss: 0.0631 - val_accuracy: 0.9771
# Epoch 73/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0756 - accuracy: 0.9760 - val_loss: 0.0555 - val_accuracy: 0.9750
# Epoch 74/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0684 - accuracy: 0.9772 - val_loss: 0.0869 - val_accuracy: 0.9750
# Epoch 75/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0480 - accuracy: 0.9823 - val_loss: 0.0622 - val_accuracy: 0.9771
# Epoch 76/80
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0407 - accuracy: 0.9868 - val_loss: 0.0441 - val_accuracy: 0.9875
# Epoch 77/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0508 - accuracy: 0.9812 - val_loss: 0.0621 - val_accuracy: 0.9771
# Epoch 78/80
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0545 - accuracy: 0.9833 - val_loss: 0.0807 - val_accuracy: 0.9688
# Epoch 79/80
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0835 - accuracy: 0.9744 - val_loss: 0.0578 - val_accuracy: 0.9833
# Epoch 80/80
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0657 - accuracy: 0.9747 - val_loss: 0.0734 - val_accuracy: 0.9833

# %%
predictions = model.predict_classes(x_test)
predictions = predictions.reshape(1,-1)[0]
cm= confusion_matrix(y_test,predictions)

print(classification_report(y_test, predictions, target_names = ['rounded (Class 1)', 'chevron (Class 0)']))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
# rounded (Class 1)       0.60      0.55      0.57        22
# chevron (Class 0)       0.58      0.64      0.61        22
#
#          accuracy                           0.59        44
#         macro avg       0.59      0.59      0.59        44
#      weighted avg       0.59      0.59      0.59        44

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(80)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = ['rouned (Class 1)', 'chevron (Class 0)']))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                    precision    recall  f1-score   support
#
#  rouned (Class 1)       1.00      0.97      0.99       240
# chevron (Class 0)       0.98      1.00      0.99       240
#
#          accuracy                           0.99       480
#         macro avg       0.99      0.99      0.99       480
#      weighted avg       0.99      0.99      0.99       480

# %%
predictions = model.predict_classes(x_test)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_test, predictions, target_names = ['rouned (Class 1)', 'chevron (Class 0)']))
# Out:
#                    precision    recall  f1-score   support
#
#  rouned (Class 1)       0.60      0.55      0.57        22
# chevron (Class 0)       0.58      0.64      0.61        22
#
#          accuracy                           0.59        44
#         macro avg       0.59      0.59      0.59        44
#      weighted avg       0.59      0.59      0.59        44
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from keras.preprocessing import image
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers[:50]]
test_image = '/content/drive/MyDrive/Ramsey_Fold_Classification_3/VAL/chevron/106.PNG'

img = image.load_img(test_image, target_size=(img_size, img_size))
img_tensor = image.img_to_array(img)
img_tensor = img_tensor.reshape(-1, img_size, img_size, 1)
# img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

layer_names = ['conv2d_1', 'activation_1', 'conv2d_2', 'activation_2', 'conv2d_5', 'activation_5']
activ_list = [activations[1], activations[3], activations[11], activations[13]]

images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activ_list):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0, :, :, col * images_per_row + row]
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image

    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='plasma')
    plt.savefig(layer_name+"_grid.jpg", bbox_inches='tight')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide

# %%
from keras.preprocessing import image
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers[:50]]
test_image = '/content/drive/MyDrive/Ramsey_Fold_Classification_3/TEST/chevron/download (13).jpg'

img = image.load_img(test_image, target_size=(img_size, img_size))
img_tensor = image.img_to_array(img)
img_tensor = img_tensor.reshape(-1, img_size, img_size, 1)
# img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

layer_names = ['conv2d_1', 'activation_1', 'conv2d_2', 'activation_2', 'conv2d_5', 'activation_5']
activ_list = [activations[1], activations[3], activations[11], activations[13]]

images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activ_list):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0, :, :, col * images_per_row + row]
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image

    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='plasma')
    plt.savefig(layer_name+"_grid.jpg", bbox_inches='tight')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
